# %% [markdown]
# # 3 split the data into training (70%) and validation (30%)
# **OBJECTIVE:** randomly split the annotated data into
# - *training* (70% of the tiles): set of data used for learning (by the model), that is, to fit the parameters to the machine learning model.
# - *validation* set (30%): Set of data used to provide an unbiased evaluation of a model fitted on the training dataset while tuning model hyperparameters.
# Also play a role in other forms of model preparation, such as feature selection, threshold cut-off selection.
#
# Normally, one would create a third test dataset for a fully independent evaluation of model's performance on unseen data. In this course the test data are already taken out of the data and will be provided later in the course.
#
#
#
# **INPUT:**
# - `path_to_tiles`="/content/drive/MyDrive/NOVA_course_deep_learning/data/tiles/10m_krakstad_202304_sun"
# -`split_train`= 0.7
#
# **OUTPUT:**
# - train and validation data organized in the following folders:
#
# ```
# ├── train
# │   ├── images
# │   └── labels
# ├── val
# │   ├── images
# │   └── labels
# ```

# %%
annotator_ID="full_data" # change this to your folder ID

path_to_tiles="/content/drive/MyDrive/content/drive/MyDrive/NOVA_course_deep_learning/data/annotated_data/train/"+str(annotator_ID)+"/all_data"

# define split for training and validation
split_train= 0.7 #
split_val=1-split_train

# %% [markdown]
# ### 3.1 Load libraries

# %%
import os
import shutil
import random

# mount google drive
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 3.2 Create train and validation directories and subdivide each into "images" and "labels" sub-directories

# %%
train_dir = os.path.join(path_to_tiles, "train")
os.makedirs(train_dir, exist_ok=True) # creates new directory for training data
val_dir = os.path.join(path_to_tiles, "val")
os.makedirs(val_dir, exist_ok=True) # creates new directory for validation data
val_img_dir = os.path.join(path_to_tiles, "val","images")
os.makedirs(val_img_dir, exist_ok=True) # creates new directory for training data
train_img_dir = os.path.join(path_to_tiles, "train","images")
os.makedirs(train_img_dir, exist_ok=True) # creates new directory for training data
val_ann_dir = os.path.join(path_to_tiles, "val","labels")
os.makedirs(val_ann_dir, exist_ok=True) # creates new directory for training data
train_ann_dir = os.path.join(path_to_tiles, "train","labels")
os.makedirs(train_ann_dir, exist_ok=True) # creates new directory for training data

# %% [markdown]
# ### 3.3 Randomly sample tiles

# %%
# Get a list of all the .txt files in the data directory
txt_files = [f for f in os.listdir(path_to_tiles) if f.endswith(".txt")]
img_files = [f for f in os.listdir(path_to_tiles) if f.endswith(".tif")]

# %%
txt_files
# Out:
# ['kolstad_190414_p4p_29_22.txt',
#  'kolstad_190414_p4p_29_20.txt',
#  'kolstad_190414_p4p_29_23.txt',
#  'kolstad_190414_p4p_35_16.txt',
#  'kolstad_190414_p4p_35_18.txt',
#  'kolstad_190414_p4p_35_20.txt',
#  'gjekstad_190410_p4p_08_08.txt',
#  'kolstad_190414_p4p_33_16.txt',
#  'kolstad_190414_p4p_33_23.txt',
#  'gjekstad_190410_p4p_09_13.txt',
#  'gjekstad_190410_p4p_06_05.txt',
#  'kolstad_190414_p4p_36_16.txt',
#  'gjekstad_190410_p4p_07_05.txt',
#  'kolstad_190414_p4p_34_12.txt',
#  'kolstad_190414_p4p_34_16.txt',
#  'kolstad_190414_p4p_39_18.txt',
#  'kolstad_190414_p4p_36_20.txt',
#  'gjekstad_190410_p4p_10_13.txt',
#  'kolstad_190414_p4p_37_11.txt',
#  'Tjunction_190416_p4p_09_22.txt',
#  'Tjunction_190416_p4p_10_06.txt',
#  'Tjunction_190416_p4p_09_23.txt',
#  'Tjunction_190416_p4p_10_12.txt',
#  'Tjunction_190416_p4p_10_24.txt',
#  'Tjunction_190416_p4p_10_10.txt',
#  'Tjunction_190416_p4p_09_26.txt',
#  'Tjunction_190416_p4p_10_22.txt',
#  'Tjunction_190416_p4p_10_23.txt',
#  'Tjunction_190416_p4p_09_24.txt',
#  'gjekstad_190410_p4p_16_30.txt',
#  'Tjunction_190416_p4p_10_25.txt',
#  'Tjunction_190416_p4p_11_04.txt',
#  'Tjunction_190416_p4p_07_12.txt',
#  'kolstad_190414_p4p_40_18.txt',
#  'Tjunction_190416_p4p_07_15.txt',
#  'Tjunction_190416_p4p_07_11.txt',
#  'Tjunction_190416_p4p_07_25.txt',
#  'Tjunction_190416_p4p_07_24.txt',
#  'Tjunction_190416_p4p_07_22.txt',
#  'Tjunction_190416_p4p_07_21.txt',
#  'kolstad_190414_p4p_41_18.txt',
#  'Tjunction_190416_p4p_08_16.txt',
#  'BruuHvitsteen_190413_p4p_37_19.txt',
#  'Tjunction_190416_p4p_08_25.txt',
#  'Tjunction_190416_p4p_08_26.txt',
#  'BruuHvitsteen_190413_p4p_37_11.txt',
#  'BruuHvitsteen_190413_p4p_37_17.txt',
#  'BruuHvitsteen_190413_p4p_37_16.txt',
#  'Tjunction_190416_p4p_08_17.txt',
#  'BruuHvitsteen_190413_p4p_38_11.txt',
#  'kolstad_190414_p4p_17_21.txt',
#  'BruuHvitsteen_190413_p4p_38_10.txt',
#  'BruuHvitsteen_190413_p4p_38_19.txt',
#  'Raanaas_190419_p4p_29_23.txt',
#  'BruuHvitsteen_190413_p4p_38_18.txt',
#  'kolstad_190414_p4p_18_21.txt',
#  'Raanaas_190419_p4p_29_25.txt',
#  'BruuHvitsteen_190413_p4p_35_11.txt',
#  'BruuHvitsteen_190413_p4p_35_10.txt',
#  'BruuHvitsteen_190413_p4p_35_16.txt',
#  'Raanaas_190419_p4p_27_12.txt',
#  'Raanaas_190419_p4p_27_15.txt',
#  'Raanaas_190419_p4p_27_25.txt',
#  'Raanaas_190419_p4p_27_27.txt',
#  'Raanaas_190419_p4p_27_26.txt',
#  'BruuHvitsteen_190413_p4p_36_15.txt',
#  'BruuHvitsteen_190413_p4p_36_16.txt',
#  'Raanaas_190419_p4p_28_27.txt',
#  'kolstad_190414_p4p_20_30.txt',
#  'BruuHvitsteen_190413_p4p_43_12.txt',
#  'Raanaas_190419_p4p_32_10.txt',
#  'Raanaas_190419_p4p_28_26.txt',
#  'Raanaas_190419_p4p_32_25.txt',
#  'kolstad_190414_p4p_21_32.txt',
#  'kolstad_190414_p4p_20_26.txt',
#  'kolstad_190414_p4p_21_20.txt',
#  'BruuHvitsteen_190413_p4p_41_16.txt',
#  'BruuHvitsteen_190413_p4p_43_19.txt',
#  'BruuHvitsteen_190413_p4p_40_13.txt',
#  'BruuHvitsteen_190413_p4p_40_17.txt',
#  'BruuHvitsteen_190413_p4p_39_16.txt',
#  'kolstad_190414_p4p_19_24.txt',
#  'Raanaas_190419_p4p_30_25.txt',
#  'kolstad_190414_p4p_19_23.txt',
#  'BruuHvitsteen_190413_p4p_40_16.txt',
#  'kolstad_190414_p4p_19_21.txt',
#  'Raanaas_190419_p4p_31_16.txt',
#  'Raanaas_190419_p4p_31_15.txt',
#  'Raanaas_190419_p4p_31_25.txt',
#  'kolstad_190414_p4p_24_17.txt',
#  'kolstad_190414_p4p_24_18.txt',
#  'BruuHvitsteen_190413_p4p_41_14.txt',
#  'kolstad_190414_p4p_25_18.txt',
#  'kolstad_190414_p4p_25_17.txt',
#  'Raanaas_190419_p4p_36_13.txt',
#  'Raanaas_190419_p4p_36_12.txt',
#  'Raanaas_190419_p4p_36_19.txt',
#  'kolstad_190414_p4p_25_21.txt',
#  'kolstad_190414_p4p_25_24.txt',
#  'kolstad_190414_p4p_25_23.txt',
#  'kolstad_190414_p4p_22_19.txt',
#  'kolstad_190414_p4p_22_30.txt',
#  'BruuHvitsteen_190413_p4p_44_13.txt',
#  'Raanaas_190419_p4p_34_11.txt',
#  'Raanaas_190419_p4p_34_25.txt',
#  'Raanaas_190419_p4p_34_26.txt',
#  'Raanaas_190419_p4p_34_23.txt',
#  'Godager_190517_p4p_11_22.txt',
#  'Godager_190517_p4p_12_22.txt',
#  'Godager_190517_p4p_09_27.txt',
#  'Godager_190517_p4p_10_27.txt',
#  'Godager_190517_p4p_10_26.txt',
#  'Godager_190517_p4p_10_29.txt',
#  'Lynne1_190421_p4p_13_13.txt',
#  'Raanaas_190419_p4p_39_17.txt',
#  'kolstad_190414_p4p_28_23.txt',
#  'Lynne1_190421_p4p_14_12.txt',
#  'Godager_190517_p4p_16_17.txt',
#  'Godager_190517_p4p_16_21.txt',
#  'Godager_190517_p4p_16_20.txt',
#  'Raanaas_190419_p4p_37_16.txt',
#  'Raanaas_190419_p4p_37_12.txt',
#  'kolstad_190414_p4p_26_19.txt',
#  'Raanaas_190419_p4p_37_13.txt',
#  'Godager_190517_p4p_14_21.txt',
#  'Godager_190517_p4p_18_20.txt',
#  'Lynne1_190421_p4p_16_11.txt',
#  'Lynne1_190421_p4p_16_10.txt',
#  'Raanaas_190419_p4p_37_25.txt',
#  'kolstad_190414_p4p_26_25.txt',
#  'Lynne1_190421_p4p_16_14.txt',
#  'Godager_190517_p4p_19_17.txt',
#  'Lynne1_190421_p4p_17_10.txt',
#  'Raanaas_190419_p4p_38_17.txt',
#  'Lynne1_190421_p4p_15_16.txt',
#  'Godager_190517_p4p_17_20.txt',
#  'Lynne1_190421_p4p_15_14.txt',
#  'Godager_190517_p4p_18_14.txt',
#  'Lynne1_190421_p4p_19_15.txt',
#  'Godager_190517_p4p_23_09.txt',
#  'Lynne1_190421_p4p_17_22.txt',
#  'Lynne1_190421_p4p_17_21.txt',
#  'Lynne1_190421_p4p_17_23.txt',
#  'Tjunction_190416_p4p_13_12.txt',
#  'Tjunction_190416_p4p_13_11.txt',
#  'Tjunction_190416_p4p_13_13.txt',
#  'Tjunction_190416_p4p_14_12.txt',
#  'Tjunction_190416_p4p_14_11.txt',
#  'Tjunction_190416_p4p_14_13.txt',
#  'Tjunction_190416_p4p_14_19.txt',
#  'Tjunction_190416_p4p_11_06.txt',
#  'Tjunction_190416_p4p_11_05.txt',
#  'Tjunction_190416_p4p_11_10.txt',
#  'Tjunction_190416_p4p_11_15.txt',
#  'Tjunction_190416_p4p_12_04.txt',
#  'Tjunction_190416_p4p_12_20.txt',
#  'Tjunction_190416_p4p_12_19.txt',
#  'Tjunction_190416_p4p_12_23.txt',
#  'Tjunction_190416_p4p_12_22.txt',
#  'Tjunction_190416_p4p_17_24.txt',
#  'Tjunction_190416_p4p_18_08.txt',
#  'Tjunction_190416_p4p_18_07.txt',
#  'Tjunction_190416_p4p_18_13.txt',
#  'Tjunction_190416_p4p_18_19.txt',
#  'Tjunction_190416_p4p_15_11.txt',
#  'Tjunction_190416_p4p_15_19.txt',
#  'Tjunction_190416_p4p_15_21.txt',
#  'Tjunction_190416_p4p_15_26.txt',
#  'Tjunction_190416_p4p_16_21.txt',
#  'Tjunction_190416_p4p_16_26.txt',
#  'Tjunction_190416_p4p_16_25.txt',
#  'Tjunction_190416_p4p_21_16.txt',
#  'Tjunction_190416_p4p_21_15.txt',
#  'Tjunction_190416_p4p_21_18.txt',
#  'Tjunction_190416_p4p_21_17.txt',
#  'Tjunction_190416_p4p_21_21.txt',
#  'Tjunction_190416_p4p_22_16.txt',
#  'Tjunction_190416_p4p_22_27.txt',
#  'Tjunction_190416_p4p_19_08.txt',
#  'Tjunction_190416_p4p_19_17.txt',
#  'Tjunction_190416_p4p_19_27.txt',
#  'Tjunction_190416_p4p_20_03.txt',
#  'Tjunction_190416_p4p_20_11.txt',
#  'Tjunction_190416_p4p_20_16.txt',
#  'Tjunction_190416_p4p_20_15.txt',
#  'Tjunction_190416_p4p_20_14.txt',
#  'Tjunction_190416_p4p_20_18.txt',
#  'Tjunction_190416_p4p_20_17.txt',
#  'Lynne1_190421_p4p_08_12.txt',
#  'Tjunction_190416_p4p_23_27.txt',
#  'Tjunction_190416_p4p_24_24.txt',
#  'Lynne1_190421_p4p_31_43.txt',
#  'Lynne1_190421_p4p_31_42.txt',
#  'Lynne1_190421_p4p_32_39.txt',
#  'Grue1_190422_p4p_07_09.txt',
#  'Grue1_190422_p4p_07_10.txt',
#  'Grue1_190422_p4p_08_08.txt',
#  'Grue1_190422_p4p_08_07.txt',
#  'Grue1_190422_p4p_08_12.txt',
#  'Grue1_190422_p4p_08_13.txt',
#  'Grue1_190422_p4p_09_11.txt',
#  'Grue1_190422_p4p_09_12.txt',
#  'Grue1_190422_p4p_05_05.txt',
#  'Grue1_190422_p4p_06_06.txt',
#  'Grue1_190422_p4p_06_05.txt',
#  'Grue1_190422_p4p_06_07.txt',
#  'Grue1_190422_p4p_14_07.txt',
#  'Grue1_190422_p4p_15_08.txt',
#  'Grue1_190422_p4p_16_08.txt',
#  'Grue1_190422_p4p_11_05.txt',
#  'Grue1_190422_p4p_11_09.txt',
#  'Grue1_190422_p4p_11_07.txt',
#  'Grue1_190422_p4p_11_06.txt',
#  'Grue1_190422_p4p_12_08.txt',
#  'Grue1_190422_p4p_12_07.txt',
#  'Grue1_190422_p4p_12_11.txt',
#  'Grue1_190422_p4p_12_10.txt',
#  'Grue1_190422_p4p_12_09.txt',
#  'Grue1_190422_p4p_13_11.txt',
#  'Grue1_190422_p4p_22_13.txt',
#  'Grue1_190422_p4p_22_12.txt',
#  'Grue1_190422_p4p_22_11.txt',
#  'Lynne2_190421_p4p_10_05.txt',
#  'Grue1_190422_p4p_23_09.txt',
#  'Grue1_190422_p4p_24_11.txt',
#  'Lynne2_190421_p4p_13_04.txt',
#  'Grue1_190422_p4p_25_09.txt',
#  'Grue1_190422_p4p_18_06.txt',
#  'Grue1_190422_p4p_19_13.txt',
#  'Grue1_190422_p4p_19_12.txt',
#  'Grue1_190422_p4p_20_08.txt',
#  'Lynne2_190421_p4p_06_05.txt',
#  'Grue1_190422_p4p_20_09.txt',
#  'Lynne2_190421_p4p_06_04.txt',
#  'Grue1_190422_p4p_20_14.txt',
#  'Lynne2_190421_p4p_07_04.txt',
#  'Grue1_190422_p4p_21_11.txt',
#  'Godager_190517_p4p_26_09.txt',
#  'Godager_190517_p4p_26_16.txt',
#  'Godager_190517_p4p_26_25.txt',
#  'Lynne1_190421_p4p_22_25.txt',
#  'Lynne1_190421_p4p_22_24.txt',
#  'Godager_190517_p4p_27_13.txt',
#  'Godager_190517_p4p_27_16.txt',
#  'Godager_190517_p4p_27_20.txt',
#  'Lynne1_190421_p4p_20_16.txt',
#  'Godager_190517_p4p_24_12.txt',
#  'Lynne1_190421_p4p_20_20.txt',
#  'Godager_190517_p4p_24_19.txt',
#  'Godager_190517_p4p_24_16.txt',
#  'Godager_190517_p4p_25_10.txt',
#  'Godager_190517_p4p_25_19.txt',
#  'Godager_190517_p4p_25_24.txt',
#  'Godager_190517_p4p_31_09.txt',
#  'Lynne1_190421_p4p_25_33.txt',
#  'Lynne1_190421_p4p_25_32.txt',
#  'Godager_190517_p4p_28_09.txt',
#  'Lynne1_190421_p4p_23_18.txt',
#  'Godager_190517_p4p_28_15.txt',
#  'Lynne1_190421_p4p_23_27.txt',
#  'Godager_190517_p4p_28_16.txt',
#  'Lynne1_190421_p4p_23_25.txt',
#  'Lynne1_190421_p4p_27_40.txt',
#  'Lynne1_190421_p4p_27_39.txt',
#  'Lynne1_190421_p4p_28_33.txt',
#  'Godager_190517_p4p_32_11.txt',
#  'Lynne1_190421_p4p_26_24.txt',
#  'Lynne1_190421_p4p_26_32.txt',
#  'Lynne1_190421_p4p_26_35.txt',
#  'Godager_190517_p4p_33_09.txt',
#  'Godager_190517_p4p_33_17.txt',
#  'Godager_190517_p4p_33_20.txt',
#  'Godager_190517_p4p_38_18.txt',
#  'Godager_190517_p4p_36_17.txt',
#  'Lynne1_190421_p4p_29_41.txt',
#  'Lynne1_190421_p4p_29_40.txt',
#  'BruuHvitsteen_190413_p4p_20_13.txt',
#  'BruuHvitsteen_190413_p4p_20_12.txt',
#  'Raanaas_190419_p4p_15_27.txt',
#  'Raanaas_190419_p4p_16_16.txt',
#  'BruuHvitsteen_190413_p4p_21_23.txt',
#  'BruuHvitsteen_190413_p4p_21_22.txt',
#  'Raanaas_190419_p4p_16_27.txt',
#  'BruuHvitsteen_190413_p4p_21_24.txt',
#  'Raanaas_190419_p4p_14_23.txt',
#  'BruuHvitsteen_190413_p4p_19_06.txt',
#  'BruuHvitsteen_190413_p4p_19_08.txt',
#  'Raanaas_190419_p4p_14_35.txt',
#  'BruuHvitsteen_190413_p4p_19_18.txt',
#  'BruuHvitsteen_190413_p4p_19_16.txt',
#  'BruuHvitsteen_190413_p4p_24_20.txt',
#  'Raanaas_190419_p4p_19_16.txt',
#  'Raanaas_190419_p4p_19_20.txt',
#  'BruuHvitsteen_190413_p4p_25_21.txt',
#  'kolstad_190414_p4p_07_19.txt',
#  'BruuHvitsteen_190413_p4p_26_12.txt',
#  'BruuHvitsteen_190413_p4p_26_16.txt',
#  'BruuHvitsteen_190413_p4p_22_13.txt',
#  'BruuHvitsteen_190413_p4p_22_17.txt',
#  'Raanaas_190419_p4p_17_20.txt',
#  'Raanaas_190419_p4p_17_26.txt',
#  'BruuHvitsteen_190413_p4p_23_05.txt',
#  'BruuHvitsteen_190413_p4p_23_11.txt',
#  'BruuHvitsteen_190413_p4p_23_08.txt',
#  'BruuHvitsteen_190413_p4p_23_19.txt',
#  'Raanaas_190419_p4p_18_16.txt',
#  'Raanaas_190419_p4p_18_23.txt',
#  'Raanaas_190419_p4p_18_22.txt',
#  'Raanaas_190419_p4p_22_16.txt',
#  'Raanaas_190419_p4p_22_18.txt',
#  'BruuHvitsteen_190413_p4p_29_22.txt',
#  'Raanaas_190419_p4p_22_26.txt',
#  'BruuHvitsteen_190413_p4p_29_21.txt',
#  'BruuHvitsteen_190413_p4p_30_11.txt',
#  'Raanaas_190419_p4p_23_14.txt',
#  'BruuHvitsteen_190413_p4p_30_10.txt',
#  'kolstad_190414_p4p_11_18.txt',
#  'Raanaas_190419_p4p_23_18.txt',
#  'BruuHvitsteen_190413_p4p_30_21.txt',
#  'Raanaas_190419_p4p_23_26.txt',
#  'BruuHvitsteen_190413_p4p_30_23.txt',
#  'Raanaas_190419_p4p_23_23.txt',
#  'Raanaas_190419_p4p_23_27.txt',
#  'Raanaas_190419_p4p_20_21.txt',
#  'kolstad_190414_p4p_08_22.txt',
#  'BruuHvitsteen_190413_p4p_27_15.txt',
#  'BruuHvitsteen_190413_p4p_27_13.txt',
#  'Raanaas_190419_p4p_21_20.txt',
#  'Raanaas_190419_p4p_21_24.txt',
#  'Raanaas_190419_p4p_21_23.txt',
#  'Raanaas_190419_p4p_21_21.txt',
#  'kolstad_190414_p4p_09_22.txt',
#  'Raanaas_190419_p4p_21_27.txt',
#  'BruuHvitsteen_190413_p4p_28_13.txt',
#  'BruuHvitsteen_190413_p4p_28_15.txt',
#  'BruuHvitsteen_190413_p4p_28_14.txt',
#  'BruuHvitsteen_190413_p4p_28_21.txt',
#  'kolstad_190414_p4p_13_20.txt',
#  'Raanaas_190419_p4p_25_25.txt',
#  'BruuHvitsteen_190413_p4p_33_22.txt',
#  'Raanaas_190419_p4p_26_12.txt',
#  'BruuHvitsteen_190413_p4p_34_13.txt',
#  'BruuHvitsteen_190413_p4p_34_10.txt',
#  'BruuHvitsteen_190413_p4p_34_16.txt',
#  'BruuHvitsteen_190413_p4p_34_14.txt',
#  'Raanaas_190419_p4p_26_25.txt',
#  'Raanaas_190419_p4p_26_22.txt',
#  'Raanaas_190419_p4p_26_26.txt',
#  'BruuHvitsteen_190413_p4p_31_10.txt',
#  'BruuHvitsteen_190413_p4p_31_23.txt',
#  'BruuHvitsteen_190413_p4p_31_22.txt',
#  'BruuHvitsteen_190413_p4p_32_11.txt',
#  'BruuHvitsteen_190413_p4p_32_15.txt',
#  'BruuHvitsteen_190413_p4p_32_22.txt',
#  'Grue1_190422_p4p_29_11.txt',
#  'Grue1_190422_p4p_29_13.txt',
#  'Raanaas_190419_p4p_25_13.txt',
#  'Grue1_190422_p4p_30_10.txt',
#  'Grue1_190422_p4p_30_11.txt',
#  'Grue1_190422_p4p_25_15.txt',
#  'Grue1_190422_p4p_25_14.txt',
#  'Grue1_190422_p4p_26_14.txt',
#  'Grue1_190422_p4p_27_12.txt',
#  'Grue1_190422_p4p_28_13.txt',
#  'Grue2_190417_p4p_04_14.txt',
#  'Grue2_190417_p4p_05_08.txt',
#  'Grue2_190417_p4p_07_08.txt',
#  'Grue2_190417_p4p_12_09.txt',
#  'Grue2_190417_p4p_12_08.txt',
#  'Grue2_190417_p4p_13_10.txt',
#  'Raanaas_190419_p4p_09_19.txt',
#  'Raanaas_190419_p4p_09_18.txt',
#  'Grue2_190417_p4p_13_11.txt',
#  'BruuHvitsteen_190413_p4p_12_19.txt',
#  'BruuHvitsteen_190413_p4p_13_19.txt',
#  'BruuHvitsteen_190413_p4p_13_18.txt',
#  'Grue2_190417_p4p_15_13.txt',
#  'BruuHvitsteen_190413_p4p_13_21.txt',
#  'Raanaas_190419_p4p_10_21.txt',
#  'Raanaas_190419_p4p_10_20.txt',
#  'Raanaas_190419_p4p_10_19.txt',
#  'Grue2_190417_p4p_08_06.txt',
#  'Raanaas_190419_p4p_07_22.txt',
#  'Grue2_190417_p4p_08_12.txt',
#  'Raanaas_190419_p4p_07_25.txt',
#  'Raanaas_190419_p4p_07_28.txt',
#  'BruuHvitsteen_190413_p4p_10_22.txt',
#  'Grue2_190417_p4p_10_08.txt',
#  'Grue2_190417_p4p_10_12.txt',
#  'Raanaas_190419_p4p_08_19.txt',
#  'Raanaas_190419_p4p_08_23.txt',
#  'Raanaas_190419_p4p_08_22.txt',
#  'Raanaas_190419_p4p_08_21.txt',
#  'Grue2_190417_p4p_11_09.txt',
#  'Raanaas_190419_p4p_08_28.txt',
#  'Raanaas_190419_p4p_08_34.txt',
#  'Raanaas_190419_p4p_08_33.txt',
#  'Grue2_190417_p4p_20_14.txt',
#  'Raanaas_190419_p4p_12_19.txt',
#  'Grue2_190417_p4p_20_13.txt',
#  'BruuHvitsteen_190413_p4p_16_13.txt',
#  'Raanaas_190419_p4p_12_35.txt',
#  'Raanaas_190419_p4p_12_33.txt',
#  'BruuHvitsteen_190413_p4p_17_11.txt',
#  'BruuHvitsteen_190413_p4p_17_09.txt',
#  'BruuHvitsteen_190413_p4p_17_08.txt',
#  'BruuHvitsteen_190413_p4p_17_15.txt',
#  'BruuHvitsteen_190413_p4p_17_13.txt',
#  'Raanaas_190419_p4p_13_35.txt',
#  'Raanaas_190419_p4p_13_33.txt',
#  'Raanaas_190419_p4p_10_36.txt',
#  'Raanaas_190419_p4p_10_35.txt',
#  'BruuHvitsteen_190413_p4p_14_17.txt',
#  'BruuHvitsteen_190413_p4p_14_16.txt',
#  'Grue2_190417_p4p_17_14.txt',
#  'BruuHvitsteen_190413_p4p_14_19.txt',
#  'BruuHvitsteen_190413_p4p_14_18.txt',
#  'Raanaas_190419_p4p_11_30.txt',
#  'Raanaas_190419_p4p_11_29.txt',
#  'Raanaas_190419_p4p_11_28.txt',
#  'BruuHvitsteen_190413_p4p_15_14.txt',
#  'Raanaas_190419_p4p_11_37.txt',
#  'kolstad_190414_p4p_31_17.txt',
#  'kolstad_190414_p4p_31_16.txt']

# %%
# remove .txt files that have no image (not sure why ?)
txt_files_with_tif = []
for txt_file in txt_files:
    # get the base name of the text file
    txt_base_name = os.path.basename(txt_file)
    # replace the file extension with .tif to get the corresponding tif file name
    img_file = os.path.join(os.path.dirname(txt_file), os.path.splitext(txt_base_name)[0] + '.tif')
    img_file=path_to_tiles+"/"+img_file
    #print("txt: "+txt_file)
    #print("tif: "+img_file)
    # check if the tif file exists
    if os.path.exists(img_file):
      #print("path to image " + img_file + " does not exist!")
      txt_files_with_tif.append(txt_file)

# %%
txt_files=txt_files_with_tif

# Shuffle the list of text files
random.shuffle(txt_files)
#train=random.sample(txt_files, )

# Calculate the number of files for the train and validation sets
train_size = int(0.7 * len(txt_files))
val_size = len(txt_files) - train_size

# %%
train_size
# Out:
# 296

# %%
val_size
# Out:
# 128

# %%
train_size + val_size
# Out:
# 424

# %%
train_dir
# Out:
# '/content/drive/MyDrive/content/drive/MyDrive/NOVA_course_deep_learning/data/annotated_data/train/full_data/all_data/train'

# %% [markdown]
# ### Move the text annotation files and respective images to the train and validation directories

# %%
# iterate through each annotated .txt file
for i, txt_file in enumerate(txt_files):
    if i < train_size:
        dest_dir = train_dir
    else:
        dest_dir = val_dir
    #print("path to "+path_to_tiles+"/"+txt_file+" exists: "+ str(os.path.exists(txt_file)))
    if os.path.exists(path_to_tiles+"/"+txt_file):
      src_file = os.path.join(path_to_tiles, txt_file)
      src_img = os.path.join(path_to_tiles, os.path.splitext(txt_file)[0]+".tif")
      if os.path.exists(src_img):
        dest_file = os.path.join(dest_dir,"labels", txt_file)
        dest_img = os.path.join(dest_dir,"images", os.path.splitext(txt_file)[0]+".tif")
        #print("copying files")
        shutil.move(src_file, dest_file)
        shutil.move(src_img, dest_img)

# %% [markdown]
# It is often also good practice to add approximately 10% of background images, i.e. that do not contain any bounding box. This will help the model to avoid to produce odd detections in areas otherwise unseen to the model.
#
# A simple (and efficient) way to do so it to scroll throught the image tiles (in google drive), select them manually and copying 70% of them in the training and 30% in the validation folders.

# %% [markdown]
# # The end. And now let's get to the fun part 🥳 to the [model training](https://colab.research.google.com/drive/1dZ4uJHNhjbMCdk0pSyhskkA7It1jKlnF)
